# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import json

# %%
with open('src/datasets.json','r') as f:
    data = json.load(f)

# %%
import pandas as pd

# %%
result = []
for dat in data:
    dataset = dat['resource']
    name = dataset['name']
    col_names = dataset['columns_name']
    col_field_names = dataset['columns_field_name']
    col_type = dataset['columns_datatype']
    col_desc = dataset['columns_description']
    
    for i, col_name in enumerate(col_names):
        result.append({'datasaet_name':name, 'col_name': col_name, 'col_field_name': col_field_names[i], 'col_type': col_type[i], 'col_desc': col_desc[i]})
        
result= pd.DataFrame(result)

# %%
result.col_name.value_counts().sort_values(ascending=True).tail(40).plot(kind='barh',figsize=(10,10))
plt.xlabel('No of datasets with column')
plt.title('Most common columns')
# Out:
# Text(0.5, 1.0, 'Most common columns')

# %%
dataset_counts =[]
for dataset in data:
    dataset_counts.append({'dataset': dataset['resource']['name'], 'downloads': dataset['resource']['download_count'], 'page_views': dataset['resource']['page_views']['page_views_total'] })
dataset_counts = pd.DataFrame(dataset_counts)
dataset_counts = dataset_counts.assign(downloads_pc = 100*dataset_counts.downloads.div(dataset_counts.downloads.sum()))
dataset_counts = dataset_counts.assign(page_view_pc = 100*dataset_counts.page_views.div(dataset_counts.page_views.sum()))

dataset_counts = dataset_counts.sort_values(by='downloads_pc', ascending=False).assign(cumulative_pc = lambda x: x.downloads_pc.cumsum())
dataset_counts = dataset_counts.sort_values(by='page_view_pc', ascending=False).assign(cumulative__page_views = lambda x: x.page_view_pc.cumsum())

# %%
attributions  = []
for d in data:
    attributions.append(d['resource']['attribution'])

# %%
pd.Series(attributions).value_counts()
# Out:
# NYC Department of Education                                                                            299
# Department of Education (DOE)                                                                          248
# Department of Education                                                                                165
# Department of Transportation (DOT)                                                                     123
# Department of Parks and Recreation (DPR)                                                               122
#                                                                                                       ...
# Department of Youth and Community Development, Runaway and Homeless Youth Services                       1
# Mayor's Office of Adult Education (ADULTED)                                                              1
# LinkUp                                                                                                   1
# Department of Environmental Protection & Department of Information Technology and Telecommunication      1
# New York City Office of Management and Budget                                                            1
# Length: 216, dtype: int64

# %%
dataset_counts.page_views.sum()
# Out:
# 16283346

# %%
[d for d in data if d['resource']['name'] == '2010 Orthoimagery Manhattan' ]
# Out:
# [{'resource': {'name': '2010 Orthoimagery Manhattan',
#    'id': 'dve9-92na',
#    'parent_fxf': None,
#    'description': 'The Department of Information Technology and Telecommunications, GIS Unit, is providing the raw orthoimagery for download. This orthoimagery is used to create the Aerial Photography Tile Layer services described in further detail here: https://maps.nyc.gov/tiles/. Full metadata on the Aerial & Orthoimagery can be found at: https://github.com/CityOfNewYork/nyc-geo-metadata/blob/master/Metadata/Metadata_AerialImagery.md \r\nThe 2010 Orthoimagery Tile Index can be used to geo-reference the individual image tiles across the City (https://data.cityofnewyork.us/City-Government/2010-Orthos-Tile-Index/chzg-3b9u)',
#    'attribution': 'Department of Information Technology & Telecommunications (DoITT), GIS Unit',
#    'attribution_link': 'https://github.com/CityOfNewYork/nyc-geo-metadata/blob/master/Metadata/Metadata_AerialImagery.md',
#    'contact_email': '',
#    'type': 'href',
#    'updatedAt': '2018-09-12T15:53:31.000Z',
#    'createdAt': '2017-08-02T21:57:40.000Z',
#    'metadata_updated_at': '2018-09-12T15:53:31.000Z',
#    'data_updated_at': '2017-08-02T21:57:40.000Z',
#    'page_views': {'page_views_last_week': 0,
#     'page_views_last_month': 0,
#     'page_views_total': 58,
#     'page_views_last_week_log': 0,
#     'page_views_last_month_log': 0,
#     'page_views_total_log': 5.882643049361842},
#    'columns_name': [],
#    'columns_field_name': [],
#    'columns_datatype': [],
#    'columns_description': [],
#    'columns_format': [],
#    'download_count': None,
#    'provenance': 'official',
#    'lens_view_type': 'href',
#    'blob_mime_type': None,
#    'hide_from_data_json': False,
#    'publication_date': '2017-08-02T21:57:47.000Z'},
#   'classification': {'categories': [],
#    'tags': [],
#    'domain_category': 'City Government',
#    'domain_tags': ['manhattan',
#     'tile',
#     'aerial',
#     'photography',
#     'ortho',
#     'gis',
#     'map',
#     'imagery'],
#    'domain_metadata': [{'key': 'Update_Automation', 'value': 'No'},
#     {'key': 'Update_Date-Made-Public', 'value': '8/3/2017'},
#     {'key': 'Update_Update-Frequency', 'value': 'Historical Data'},
#     {'key': 'Dataset-Information_Agency',
#      'value': 'Department of Information Technology & Telecommunications (DoITT)'}]},
#   'metadata': {'domain': 'data.cityofnewyork.us',
#    'license': 'Creative Commons Attribution 4.0 International',
#    'additional_access_points': [{'urls': {'zip': 'https://s3.amazonaws.com/sa-static-customer-assets-us-east-1-fedramp-prod/data.cityofnewyork.us/Map_Downloads/2010_orthos/Manhattan.zip'}}]},
#   'permalink': 'https://data.cityofnewyork.us/d/dve9-92na',
#   'link': 'https://data.cityofnewyork.us/City-Government/2010-Orthoimagery-Manhattan/dve9-92na',
#   'owner': {'id': '5fuc-pqz2', 'display_name': 'NYC OpenData'}}]

# %%
plt.figure(figsize=(8,8))
dataset_counts.set_index('dataset').head(20).iloc[::-1].downloads_pc.plot(kind='barh')
plt.xlabel('% downloads')
plt.ylabel(None)
plt.title('Top 20 datasets by % of downloads')
# Out:
# Text(0.5, 1.0, 'Top 20 datasets by % of downloads')

# %%
plt.figure(figsize=(8,8))
dataset_counts.set_index('dataset').sort_values(by='page_view_pc',ascending=False).head(20).iloc[::-1].page_view_pc.plot(kind='barh')
plt.xlabel('% page views')
plt.ylabel(None)
plt.title('Top 20 datasets by % of page views')
# Out:
# Text(0.5, 1.0, 'Top 20 datasets by % of page views')

# %%
dataset_counts.sort_values(by='downloads_pc', ascending=False).head(20)
# Out:
#                                               dataset  downloads  page_views  \
# 2739               Demographic Statistics By Zip Code   917173.0       48689
# 1539                        Overhead Electronic Signs   429285.0         450
# 2710        311 Service Requests from 2010 to Present   388068.0      345537
# 2711                       Medallion Drivers - Active   266725.0      256540
# 2414                     Hurricane Evacuation Centers   206768.0        4758
# 2707                 For Hire Vehicles (FHV) - Active   201444.0     1245008
# 2715                                 Subway Entrances   196858.0      183238
# 2746                                 Police Precincts   190073.0       40619
# 2660  Sea Level Rise Maps (2020s 100-year Floodplain)   187506.0       10883
# 2094                                   Fire Companies   182690.0        1013
# 2732                                 School Districts   182483.0       59082
# 2708         For Hire Vehicles (FHV) - Active Drivers   174752.0      805663
# 2478                                  IDNYC Locations   135454.0        3500
# 2606                  Directory Of Homebase Locations   116305.0       17146
# 2719                 Medallion  Vehicles - Authorized   113020.0      122758
# 2410                            Voting/Poll Sites Map   109628.0        4855
# 2759                               Popular Baby Names    96211.0       28024
# 2723       77048      0.276367      0.473171      61.391480
#
#       cumulative__page_views
# 2704               13.691394
# 2705               24.021641
# 2706               33.119268
# 2707               40.765166
# 2708               45.712939
# 2709               47.960155
# 2710               50.082182
# 2711               51.657657
# 2712               53.105658
# 2713               54.467755
# 2714               55.726581
# 2715               56.851890
# 2716               57.841386
# 2717               58.734311
# 2718               59.524480
# 2719               60.278367
# 2720               60.967709
# 2721               61.474110
# 2722               61.968867
# 2723               62.442037

# %%
data[0]['resource']['page_views']['page_views_total']
# Out:
# 2214810

# %%
dataset_counts.shape
# Out:
# (100, 6)

# %%
dataset_counts
# Out:
#                                       dataset  downloads  page_views  \
# 32         Demographic Statistics By Zip Code     841845       43501
# 6   311 Service Requests from 2010 to Present     381640      302508
# 7                  Medallion Drivers - Active     256589      242834
# 30                           School Districts     178982       44309
# 10                           Subway Entrances     174058      174317
# ..                                        ...        ...         ...
# 69                 2015 Yellow Taxi Trip Data         19       20166
# 59               Real-Time Traffic Speed Data         19       23055
# 50         Open Parking and Camera Violations         18       28836
# 71                    311 Call Center Inquiry         14       19946
# 97                  Citywide Crime Statistics          4       15075
#
#     downloads_pc  page_view_pc  cumulative_pc
# 32     23.049665      0.372854      23.049665
# 6      10.449280      2.592842      33.498945
# 7       7.025391      2.081367      40.524337
# 30      4.900516      0.379779      45.424853
# 10      4.765698      1.494098      50.190551
# ..           ...           ...            ...
# 69      0.000520      0.172846      99.998494
# 59      0.000520      0.197608      99.999014
# 50      0.000493      0.247158      99.999507
# 71      0.000383      0.170960      99.999890
# 97      0.000110      0.129210     100.000000
#
# [100 rows x 6 columns]

# %%
dataset_counts.shape
# Out:
# (2804, 6)

# %%
dataset_counts[dataset_counts.page_views>0].sort_values(by="page_views").head(200)
# Out:
#                                                dataset  downloads  page_views  \
# 3               BP Appointments - Miscellaneous Boards      153.0           6
# 2                                   Parks Permit Areas      222.0           8
# 1        CB 106 Active Parking Lot and Garage Licenses        1.0           8
# 103  2012-13 Discharge Reporting Students with Disa...       82.0           9
# 0             2010-11 Discharge Reporting by Code - HS       87.0           9
# ..                                                 ...        ...         ...
# 113  Department for the Aging (DFTA) Reported Line ...      224.0          36
# 110           2013-14 Discharge Reporting By Code - HS       90.0          36
# 108                     2014 - 2015 Co-Location Report       90.0          36
# 107   2010-11 Transfer or Discharge Code - Grades 9-12       89.0          36
# 109              2016 - 2017 Guidance Counselor Report       83.0          36
#
#      downloads_pc  page_view_pc  cumulative_pc  cumulative__page_views
# 3        0.001862      0.000037      99.339025              100.000000
# 2        0.002702      0.000049      98.844764               99.999963
# 1        0.000012      0.000049     100.000000               99.999914
# 103      0.000998      0.000055      99.894132               99.999754
# 0        0.001059      0.000055      99.843657               99.999865
# ..            ...           ...            ...                     ...
# 113      0.002726      0.000221      98.831205               99.970774
# 110      0.001095      0.000221      99.800460               99.970553
# 108      0.001095      0.000221      99.807033               99.970332
# 107      0.001083      0.000221      99.822259               99.970111
# 109      0.001010      0.000221      99.889142               99.969889
#
# [200 rows x 7 columns]
